# %%
import requests
response = requests.get('https://www.jma.go.jp/bosai/forecast/data/forecast/130000.json')

# %%
data = response.json()
data
# Out:
# [{'publishingOffice': '気象庁',
#   'reportDatetime': '2025-05-07T17:00:00+09:00',
#   'timeSeries': [{'timeDefines': ['2025-05-07T17:00:00+09:00',
#      '2025-05-08T00:00:00+09:00',
#      '2025-05-09T00:00:00+09:00'],
#     'areas': [{'area': {'name': '東京地方', 'code': '130010'},
#       'weatherCodes': ['200', '211', '212'],
#       'weathers': ['くもり\u3000所により\u3000夜\u3000雨',
#        'くもり\u3000昼前\u3000から\u3000晴れ\u3000所により\u3000明け方\u3000まで\u3000雨',
#        'くもり\u3000後\u3000一時\u3000雨'],
#       'winds': ['北西の風\u3000後\u3000北の風\u3000２３区西部\u3000では\u3000はじめ\u3000北西の風\u3000やや強く',
#        '北東の風\u3000後\u3000南東の風',
#        '南の風'],
#       'waves': ['１メートル\u3000後\u3000０．５メートル', '０．５メートル', '０．５メートル']},
#      {'area': {'name': '伊豆諸島北部', 'code': '130020'},
#       'weatherCodes': ['111', '210', '200'],
#       'weathers': ['晴れ\u3000夜遅く\u3000くもり',
#        'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ',
#        'くもり'],
#       'winds': ['北東の風',
#        '北東の風\u3000やや強く\u3000後\u3000東の風',
#        '東の風\u3000後\u3000南の風'],
#       'waves': ['１．５メートル\u3000ただし\u3000新島\u3000では\u3000２メートル\u3000後\u3000１．５メートル',
#        '１．５メートル\u3000ただし\u3000新島\u3000では\u3000２メートル\u3000後\u3000１．５メートル',
#        '１．５メートル\u3000ただし\u3000新島\u3000では\u3000１．５メートル\u3000後\u3000２メートル']},
#      {'area': {'name': '伊豆諸島南部', 'code': '130030'},
#       'weatherCodes': ['111', '210', '200'],
#       'weathers': ['晴れ\u3000夜遅く\u3000くもり',
#        'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ',
#        'くもり'],
#       'winds': ['西の風\u3000後\u3000北西の風',
#        '北西の風\u3000後\u3000東の風\u3000やや強く',
#        '東の風\u3000後\u3000南の風\u3000やや強く'],
#       'waves': ['２．５メートル\u3000後\u3000２メートル',
#        '２メートル',
#        '１．５メートル\u3000後\u3000２メートル']},
#      {'area': {'name': '小笠原諸島', 'code': '130040'},
#       'weatherCodes': ['214', '302', '201'],
#       'weathers': ['くもり\u3000夜遅く\u3000雨\u3000所により\u3000雷\u3000を伴う',
#        '雨\u3000昼過ぎ\u3000から\u3000時々\u3000くもり\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う',
#        'くもり\u3000時々\u3000晴れ'],
#       'winds': ['南西の風\u3000後\u3000北西の風',
#        '北の風\u3000やや強く\u3000後\u3000北東の風',
#        '北東の風\u3000後\u3000東の風'],
#       'waves': ['１．５メートル',
#        '１．５メートル\u3000後\u3000２メートル',
#        '２メートル\u3000後\u3000２．５メートル']}]},
#    {'timeDefines': ['2025-05-07T18:00:00+09:00',
#      '2025-05-08T00:00:00+09:00',
#      '2025-05-08T06:00:00+09:00',
#      '2025-05-08T12:00:00+09:00',
#      '2025-05-08T18:00:00+09:00'],
#     'areas': [{'area': {'name': '東京地方', 'code': '130010'},
#       'pops': ['20', '20', '10', '10', '0']},
#      {'area': {'name': '伊豆諸島北部', 'code': '130020'},
#       'pops': ['10', '10', '10', '10', '10']},
#      {'area': {'name': '伊豆諸島南部', 'code': '130030'},
#       'pops': ['10', '10', '20', '20', '10']},
#      {'area': {'name': '小笠原諸島', 'code': '130040'},
#       'pops': ['60', '60', '50', '50', '50']}]},
#    {'timeDefines': ['2025-05-08T00:00:00+09:00', '2025-05-08T09:00:00+09:00'],
#     'areas': [{'area': {'name': '東京', 'code': '44132'}, 'temps': ['13', '22']},
#      {'area': {'name': '大島', 'code': '44172'}, 'temps': ['13', '20']},
#      {'area': {'name': '八丈島', 'code': '44263'}, 'temps': ['15', '22']},
#      {'area': {'name': '父島', 'code': '44301'}, 'temps': ['20', '24']}]}]},
#  {'publishingOffice': '気象庁',
#   'reportDatetime': '2025-05-07T17:00:00+09:00',
#   'timeSeries': [{'timeDefines': ['2025-05-08T00:00:00+09:00',
#      '2025-05-09T00:00:00+09:00',
#      '2025-05-10T00:00:00+09:00',
#      '2025-05-11T00:00:00+09:00',
#      '2025-05-12T00:00:00+09:00',
#      '2025-05-13T00:00:00+09:00',
#      '2025-05-14T00:00:00+09:00'],
#     'areas': [{'area': {'name': '東京地方', 'code': '130010'},
#       'weatherCodes': ['211', '212', '203', '200', '201', '101', '101'],
#       'pops': ['', '50', '80', '40', '20', '20', '20'],
#       'reliabilities': ['', '', 'A', 'B', 'B', 'A', 'A']},
#      {'area': {'name': '伊豆諸島', 'code': '130100'},
#       'weatherCodes': ['210', '200', '203', '202', '202', '201', '101'],
#       'pops': ['', '30', '80', '50', '50', '30', '20'],
#       'reliabilities': ['', '', 'A', 'C', 'C', 'A', 'A']},
#      {'area': {'name': '小笠原諸島', 'code': '130040'},
#       'weatherCodes': ['302', '201', '101', '101', '201', '202', '201'],
#       'pops': ['', '30', '20', '20', '30', '50', '30'],
#       'reliabilities': ['', '', 'A', 'A', 'A', 'C', 'A']}]},
#    {'timeDefines': ['2025-05-08T00:00:00+09:00',
#      '2025-05-09T00:00:00+09:00',
#      '2025-05-10T00:00:00+09:00',
#      '2025-05-11T00:00:00+09:00',
#      '2025-05-12T00:00:00+09:00',
#      '2025-05-13T00:00:00+09:00',
#      '2025-05-14T00:00:00+09:00'],
#     'areas': [{'area': {'name': '東京', 'code': '44132'},
#       'tempsMin': ['', '13', '14', '17', '15', '16', '16'],
#       'tempsMinUpper': ['', '14', '16', '18', '17', '17', '18'],
#       'tempsMinLower': ['', '11', '13', '13', '12', '14', '14'],
#       'tempsMax': ['', '23', '19', '26', '24', '26', '27'],
#       'tempsMaxUpper': ['', '26', '23', '28', '28', '29', '29'],
#       'tempsMaxLower': ['', '22', '18', '24', '21', '21', '24']},
#      {'area': {'name': '八丈島', 'code': '44263'},
#       'tempsMin': ['', '15', '17', '17', '17', '16', '16'],
#       'tempsMinUpper': ['', '17', '19', '19', '18', '18', '19'],
#       'tempsMinLower': ['', '14', '16', '14', '13', '14', '14'],
#       'tempsMax': ['', '22', '22', '22', '21', '22', '23'],
#       'tempsMaxUpper': ['', '23', '23', '25', '24', '25', '24'],
#       'tempsMaxLower': ['', '20', '20', '21', '20', '20', '21']},
#      {'area': {'name': '父島', 'code': '44301'},
#       'tempsMin': ['', '20', '22', '23', '23', '22', '22'],
#       'tempsMinUpper': ['', '23', '23', '25', '25', '24', '24'],
#       'tempsMinLower': ['', '19', '20', '22', '22', '21', '20'],
#       'tempsMax': ['', '25', '27', '28', '28', '27', '27'],
#       'tempsMaxUpper': ['', '26', '28', '29', '29', '29', '29'],
#       'tempsMaxLower': ['', '24', '26', '27', '27', '26', '25']}]}],
#   'tempAverage': {'areas': [{'area': {'name': '東京', 'code': '44132'},
#      'min': '13.8',
#      'max': '23.0'},
#     {'area': {'name': '八丈島', 'code': '44263'}, 'min': '15.9', 'max': '21.4'},
#     {'area': {'name': '父島', 'code': '44301'}, 'min': '21.1', 'max': '25.4'}]},
#   'precipAverage': {'areas': [{'area': {'name': '東京', 'code': '44132'},
#      'min': '13.9',
#      'max': '30.8'},
#     {'area': {'name': '八丈島', 'code': '44263'}, 'min': '27.4', 'max': '62.8'},
#     {'area': {'name': '父島', 'code': '44301'}, 'min': '4.5', 'max': '30.3'}]}}]

# %%
from pprint import pprint

for row in data:
    for key,value in row.items():
        pprint(f"{key}:{value}")
# Out:
# 'publishingOffice:気象庁'
# 'reportDatetime:2025-05-07T17:00:00+09:00'
# ("timeSeries:[{'timeDefines': ['2025-05-07T17:00:00+09:00', "
#  "'2025-05-08T00:00:00+09:00', '2025-05-09T00:00:00+09:00'], 'areas': "
#  "[{'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['200', '211', "
#  "'212'], 'weathers': ['くもり\\u3000所により\\u3000夜\\u3000雨', "
#  "'くもり\\u3000昼前\\u3000から\\u3000晴れ\\u3000所により\\u3000明け方\\u3000まで\\u3000雨', "
#  "'くもり\\u3000後\\u3000一時\\u3000雨'], 'winds': "
#  "['北西の風\\u3000後\\u3000北の風\\u3000２３区西部\\u3000では\\u3000はじめ\\u3000北西の風\\u3000やや強く', "
#  "'北東の風\\u3000後\\u3000南東の風', '南の風'], 'waves': ['１メートル\\u3000後\\u3000０．５メートル', "
#  "'０．５メートル', '０．５メートル']}, {'area': {'name': '伊豆諸島北部', 'code': '130020'}, "
#  "'weatherCodes': ['111', '210', '200'], 'weathers': "
#  "['晴れ\\u3000夜遅く\\u3000くもり', 'くもり\\u3000昼過ぎ\\u3000から\\u3000時々\\u3000晴れ', "
#  "'くもり'], 'winds': ['北東の風', '北東の風\\u3000やや強く\\u3000後\\u3000東の風', "
#  "'東の風\\u3000後\\u3000南の風'], 'waves': "
#  "['１．５メートル\\u3000ただし\\u3000新島\\u3000では\\u3000２メートル\\u3000後\\u3000１．５メートル', "
#  "'１．５メートル\\u3000ただし\\u3000新島\\u3000では\\u3000２メートル\\u3000後\\u3000１．５メートル', "
#  "'１．５メートル\\u3000ただし\\u3000新島\\u3000では\\u3000１．５メートル\\u3000後\\u3000２メートル']}, "
#  "{'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'weatherCodes': ['111', "
#  "'210', '200'], 'weathers': ['晴れ\\u3000夜遅く\\u3000くもり', "
#  "'くもり\\u3000昼過ぎ\\u3000から\\u3000時々\\u3000晴れ', 'くもり'], 'winds': "
#  "['西の風\\u3000後\\u3000北西の風', '北西の風\\u3000後\\u3000東の風\\u3000やや強く', "
#  "'東の風\\u3000後\\u3000南の風\\u3000やや強く'], 'waves': "
#  "['２．５メートル\\u3000後\\u3000２メートル', '２メートル', '１．５メートル\\u3000後\\u3000２メートル']}, "
#  "{'area': {'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['214', '302', "
#  "'201'], 'weathers': ['くもり\\u3000夜遅く\\u3000雨\\u3000所により\\u3000雷\\u3000を伴う', "
#  "'雨\\u3000昼過ぎ\\u3000から\\u3000時々\\u3000くもり\\u3000所により\\u3000昼前\\u3000まで\\u3000雷\\u3000を伴う', "
#  "'くもり\\u3000時々\\u3000晴れ'], 'winds': ['南西の風\\u3000後\\u3000北西の風', "
#  "'北の風\\u3000やや強く\\u3000後\\u3000北東の風', '北東の風\\u3000後\\u3000東の風'], 'waves': "
#  "['１．５メートル', '１．５メートル\\u3000後\\u3000２メートル', "
#  "'２メートル\\u3000後\\u3000２．５メートル']}]}, {'timeDefines': "
#  "['2025-05-07T18:00:00+09:00', '2025-05-08T00:00:00+09:00', "
#  "'2025-05-08T06:00:00+09:00', '2025-05-08T12:00:00+09:00', "
#  "'2025-05-08T18:00:00+09:00'], 'areas': [{'area': {'name': '東京地方', 'code': "
#  "'130010'}, 'pops': ['20', '20', '10', '10', '0']}, {'area': {'name': "
#  "'伊豆諸島北部', 'code': '130020'}, 'pops': ['10', '10', '10', '10', '10']}, "
#  "{'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'pops': ['10', '10', '20', "
#  "'20', '10']}, {'area': {'name': '小笠原諸島', 'code': '130040'}, 'pops': ['60', "
#  "'60', '50', '50', '50']}]}, {'timeDefines': ['2025-05-08T00:00:00+09:00', "
#  "'2025-05-08T09:00:00+09:00'], 'areas': [{'area': {'name': '東京', 'code': "
#  "'44132'}, 'temps': ['13', '22']}, {'area': {'name': '大島', 'code': '44172'}, "
#  "'temps': ['13', '20']}, {'area': {'name': '八丈島', 'code': '44263'}, 'temps': "
#  "['15', '22']}, {'area': {'name': '父島', 'code': '44301'}, 'temps': ['20', "
#  "'24']}]}]")
# 'publishingOffice:気象庁'
# 'reportDatetime:2025-05-07T17:00:00+09:00'
# ("timeSeries:[{'timeDefines': ['2025-05-08T00:00:00+09:00', "
#  "'2025-05-09T00:00:00+09:00', '2025-05-10T00:00:00+09:00', "
#  "'2025-05-11T00:00:00+09:00', '2025-05-12T00:00:00+09:00', "
#  "'2025-05-13T00:00:00+09:00', '2025-05-14T00:00:00+09:00'], 'areas': "
#  "[{'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['211', '212', "
#  "'203', '200', '201', '101', '101'], 'pops': ['', '50', '80', '40', '20', "
#  "'20', '20'], 'reliabilities': ['', '', 'A', 'B', 'B', 'A', 'A']}, {'area': "
#  "{'name': '伊豆諸島', 'code': '130100'}, 'weatherCodes': ['210', '200', '203', "
#  "'202', '202', '201', '101'], 'pops': ['', '30', '80', '50', '50', '30', "
#  "'20'], 'reliabilities': ['', '', 'A', 'C', 'C', 'A', 'A']}, {'area': "
#  "{'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['302', '201', '101', "
#  "'101', '201', '202', '201'], 'pops': ['', '30', '20', '20', '30', '50', "
#  "'30'], 'reliabilities': ['', '', 'A', 'A', 'A', 'C', 'A']}]}, "
#  "{'timeDefines': ['2025-05-08T00:00:00+09:00', '2025-05-09T00:00:00+09:00', "
#  "'2025-05-10T00:00:00+09:00', '2025-05-11T00:00:00+09:00', "
#  "'2025-05-12T00:00:00+09:00', '2025-05-13T00:00:00+09:00', "
#  "'2025-05-14T00:00:00+09:00'], 'areas': [{'area': {'name': '東京', 'code': "
#  "'44132'}, 'tempsMin': ['', '13', '14', '17', '15', '16', '16'], "
#  "'tempsMinUpper': ['', '14', '16', '18', '17', '17', '18'], 'tempsMinLower': "
#  "['', '11', '13', '13', '12', '14', '14'], 'tempsMax': ['', '23', '19', '26', "
#  "'24', '26', '27'], 'tempsMaxUpper': ['', '26', '23', '28', '28', '29', "
#  "'29'], 'tempsMaxLower': ['', '22', '18', '24', '21', '21', '24']}, {'area': "
#  "{'name': '八丈島', 'code': '44263'}, 'tempsMin': ['', '15', '17', '17', '17', "
#  "'16', '16'], 'tempsMinUpper': ['', '17', '19', '19', '18', '18', '19'], "
#  "'tempsMinLower': ['', '14', '16', '14', '13', '14', '14'], 'tempsMax': ['', "
#  "'22', '22', '22', '21', '22', '23'], 'tempsMaxUpper': ['', '23', '23', '25', "
#  "'24', '25', '24'], 'tempsMaxLower': ['', '20', '20', '21', '20', '20', "
#  "'21']}, {'area': {'name': '父島', 'code': '44301'}, 'tempsMin': ['', '20', "
#  "'22', '23', '23', '22', '22'], 'tempsMinUpper': ['', '23', '23', '25', '25', "
#  "'24', '24'], 'tempsMinLower': ['', '19', '20', '22', '22', '21', '20'], "
#  "'tempsMax': ['', '25', '27', '28', '28', '27', '27'], 'tempsMaxUpper': ['', "
#  "'26', '28', '29', '29', '29', '29'], 'tempsMaxLower': ['', '24', '26', '27', "
#  "'27', '26', '25']}]}]")
# ("tempAverage:{'areas': [{'area': {'name': '東京', 'code': '44132'}, 'min': "
#  "'13.8', 'max': '23.0'}, {'area': {'name': '八丈島', 'code': '44263'}, 'min': "
#  "'15.9', 'max': '21.4'}, {'area': {'name': '父島', 'code': '44301'}, 'min': "
#  "'21.1', 'max': '25.4'}]}")
# ("precipAverage:{'areas': [{'area': {'name': '東京', 'code': '44132'}, 'min': "
#  "'13.9', 'max': '30.8'}, {'area': {'name': '八丈島', 'code': '44263'}, 'min': "
#  "'27.4', 'max': '62.8'}, {'area': {'name': '父島', 'code': '44301'}, 'min': "
#  "'4.5', 'max': '30.3'}]}")

# %%
areas = []
waves = []
weathers = []
winds = []
for row in data:
    for ts in row["timeSeries"]:
        for area_info in ts["areas"]:
            print(area_info)
            name = area_info["area"]["name"]
            wave = area_info.get("waves")
            weat = area_info.get("weathers")
            wind = area_info.get("winds")
            areas.append(name)
            waves.append(wave)
            weathers.append(weat)
            winds.append(wind)
print(areas)
# Out:
# {'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['200', '211', '212'], 'weathers': ['くもり\u3000所により\u3000夜\u3000雨', 'くもり\u3000昼前\u3000から\u3000晴れ\u3000所により\u3000明け方\u3000まで\u3000雨', 'くもり\u3000後\u3000一時\u3000雨'], 'winds': ['北西の風\u3000後\u3000北の風\u3000２３区西部\u3000では\u3000はじめ\u3000北西の風\u3000やや強く', '北東の風\u3000後\u3000南東の風', '南の風'], 'waves': ['１メートル\u3000後\u3000０．５メートル', '０．５メートル', '０．５メートル']}
# {'area': {'name': '伊豆諸島北部', 'code': '130020'}, 'weatherCodes': ['111', '210', '200'], 'weathers': ['晴れ\u3000夜遅く\u3000くもり', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ', 'くもり'], 'winds': ['北東の風', '北東の風\u3000やや強く\u3000後\u3000東の風', '東の風\u3000後\u3000南の風'], 'waves': ['１．５メートル\u3000ただし\u3000新島\u3000では\u3000２メートル\u3000後\u3000１．５メートル', '１．５メートル\u3000ただし\u3000新島\u3000では\u3000２メートル\u3000後\u3000１．５メートル', '１．５メートル\u3000ただし\u3000新島\u3000では\u3000１．５メートル\u3000後\u3000２メートル']}
# {'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'weatherCodes': ['111', '210', '200'], 'weathers': ['晴れ\u3000夜遅く\u3000くもり', 'くもり\u3000昼過ぎ\u3000から\u3000時々\u3000晴れ', 'くもり'], 'winds': ['西の風\u3000後\u3000北西の風', '北西の風\u3000後\u3000東の風\u3000やや強く', '東の風\u3000後\u3000南の風\u3000やや強く'], 'waves': ['２．５メートル\u3000後\u3000２メートル', '２メートル', '１．５メートル\u3000後\u3000２メートル']}
# {'area': {'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['214', '302', '201'], 'weathers': ['くもり\u3000夜遅く\u3000雨\u3000所により\u3000雷\u3000を伴う', '雨\u3000昼過ぎ\u3000から\u3000時々\u3000くもり\u3000所により\u3000昼前\u3000まで\u3000雷\u3000を伴う', 'くもり\u3000時々\u3000晴れ'], 'winds': ['南西の風\u3000後\u3000北西の風', '北の風\u3000やや強く\u3000後\u3000北東の風', '北東の風\u3000後\u3000東の風'], 'waves': ['１．５メートル', '１．５メートル\u3000後\u3000２メートル', '２メートル\u3000後\u3000２．５メートル']}
# {'area': {'name': '東京地方', 'code': '130010'}, 'pops': ['20', '20', '10', '10', '0']}
# {'area': {'name': '伊豆諸島北部', 'code': '130020'}, 'pops': ['10', '10', '10', '10', '10']}
# {'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'pops': ['10', '10', '20', '20', '10']}
# {'area': {'name': '小笠原諸島', 'code': '130040'}, 'pops': ['60', '60', '50', '50', '50']}
# {'area': {'name': '東京', 'code': '44132'}, 'temps': ['13', '22']}
# {'area': {'name': '大島', 'code': '44172'}, 'temps': ['13', '20']}
# {'area': {'name': '八丈島', 'code': '44263'}, 'temps': ['15', '22']}
# {'area': {'name': '父島', 'code': '44301'}, 'temps': ['20', '24']}
# {'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['211', '212', '203', '200', '201', '101', '101'], 'pops': ['', '50', '80', '40', '20', '20', '20'], 'reliabilities': ['', '', 'A', 'B', 'B', 'A', 'A']}
# {'area': {'name': '伊豆諸島', 'code': '130100'}, 'weatherCodes': ['210', '200', '203', '202', '202', '201', '101'], 'pops': ['', '30', '80', '50', '50', '30', '20'], 'reliabilities': ['', '', 'A', 'C', 'C', 'A', 'A']}
# {'area': {'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['302', '201', '101', '101', '201', '202', '201'], 'pops': ['', '30', '20', '20', '30', '50', '30'], 'reliabilities': ['', '', 'A', 'A', 'A', 'C', 'A']}
# {'area': {'name': '東京', 'code': '44132'}, 'tempsMin': ['', '13', '14', '17', '15', '16', '16'], 'tempsMinUpper': ['', '14', '16', '18', '17', '17', '18'], 'tempsMinLower': ['', '11', '13', '13', '12', '14', '14'], 'tempsMax': ['', '23', '19', '26', '24', '26', '27'], 'tempsMaxUpper': ['', '26', '23', '28', '28', '29', '29'], 'tempsMaxLower': ['', '22', '18', '24', '21', '21', '24']}
# {'area': {'name': '八丈島', 'code': '44263'}, 'tempsMin': ['', '15', '17', '17', '17', '16', '16'], 'tempsMinUpper': ['', '17', '19', '19', '18', '18', '19'], 'tempsMinLower': ['', '14', '16', '14', '13', '14', '14'], 'tempsMax': ['', '22', '22', '22', '21', '22', '23'], 'tempsMaxUpper': ['', '23', '23', '25', '24', '25', '24'], 'tempsMaxLower': ['', '20', '20', '21', '20', '20', '21']}
# {'area': {'name': '父島', 'code': '44301'}, 'tempsMin': ['', '20', '22', '23', '23', '22', '22'], 'tempsMinUpper': ['', '23', '23', '25', '25', '24', '24'], 'tempsMinLower': ['', '19', '20', '22', '22', '21', '20'], 'tempsMax': ['', '25', '27', '28', '28', '27', '27'], 'tempsMaxUpper': ['', '26', '28', '29', '29', '29', '29'], 'tempsMaxLower': ['', '24', '26', '27', '27', '26', '25']}
# ['東京地方', '伊豆諸島北部', '伊豆諸島南部', '小笠原諸島', '東京地方', '伊豆諸島北部', '伊豆諸島南部', '小笠原諸島', '東京', '大島', '八丈島', '父島', '東京地方', '伊豆諸島', '小笠原諸島', '東京', '八丈島', '父島']

# %%
import pandas as pd
df = pd.DataFrame({'name': areas,
                   'waves':waves,
                   'weathers':weathers,
                   'winds':winds})

df.to_csv('name.csv',index = False)
